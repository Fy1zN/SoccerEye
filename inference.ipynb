# %%
from ultralytics import YOLO

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
model = YOLO("yolov8x.pt")  # load a pretrained YOLOv8n model

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith((".mp4", ".avi", ".mov")):
            print(os.path.join(root, file))
# Out:
# .\Input_data\08fd33_4.mp4

# %%
import os

os.chdir(r"C:\Users\KRISH MALHOTRA\OneDrive\Documents\SoccerEye")
print(os.getcwd())
# Out:
# C:\Users\KRISH MALHOTRA\OneDrive\Documents\SoccerEye

# %%
from ultralytics import YOLO
import torch

model = YOLO("models/best.pt") 
results = model.predict(
    source="Input_data/08fd33_4.mp4",
    save=True,
    device=0,
    project="runs",
    name="football",
    exist_ok=True
)

print("DONE")
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) c:\Users\KRISH MALHOTRA\OneDrive\Documents\SoccerEye\Input_data\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 111.0ms
# video 1/1 (frame 2/750) c:\Users\KRISH MALHOTRA\OneDrive\Documents\SoccerEye\Input_data\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 51.9ms
# ...

# %%
import os

path = r"C:\Users\KRISH MALHOTRA\OneDrive\Documents\SoccerEye\output"

print(os.path.exists(path))
print(os.listdir(path))
# Out:
# True
# ['08fd33_4.avi']

# %%
import utils.video_utils as vu

print(dir(vu))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
import importlib
import utils.video_utils

importlib.reload(utils.video_utils)

print(dir(utils.video_utils))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'cv2', 'os', 'read_video', 'save_video']

# %%
from utils.video_utils import read_video, save_video

video_frames = read_video("Input_data/08fd33_4.mp4")

print(len(video_frames))
print(video_frames[0].shape)
# Out:
# 750
# (1080, 1920, 3)

# %%
save_video(
    video_frames[:100],
    "output/test_output.avi"
)
